# %%
import glob 
import os
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F  # activation function
import torch.optim as optim
from tqdm import tqdm
import matplotlib.pyplot as plt

import poisevae

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20
plt.rcParams['font.weight'] = 'normal'
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['text.usetex'] = False

# %%
HOME_PATH = os.path.expanduser('~')

# %%
class EncMNIST(nn.Module):
    def __init__(self, latent_dim):
        super(EncMNIST, self).__init__()
        self.latent_dim = latent_dim
        self.dim_MNIST = 28 * 28

        self.enc1 = nn.Linear(self.dim_MNIST, 400)
        self.enc_mu = nn.Linear(400, latent_dim)
        self.enc_var = nn.Linear(400, latent_dim)

    def forward(self, x):
        x = F.relu(self.enc1(x))
        mu = self.enc_mu(x)
        log_var = self.enc_var(x)
        return mu, log_var

class DecMNIST(nn.Module):
    def __init__(self, latent_dim):
        super(DecMNIST, self).__init__()  
        self.latent_dim = latent_dim
        self.dim_MNIST   = 28 * 28
        
        self.dec = nn.Sequential(nn.Linear(self.latent_dim, 400), 
                                 nn.ReLU(inplace=True), 
                                 nn.Linear(400, self.dim_MNIST))
        
    def forward(self, x):
        return self.dec(x)

# %%
class EncSVHN(nn.Module):
    def __init__(self, latent_dim):
        super(EncSVHN, self).__init__()
        self.latent_dim = latent_dim
        
        n_channels = (3, 32, 64, 128)
        kernels = (4, 4, 4)
        strides = (2, 2, 2)
        paddings = (1, 1, 1)
        li = []
        for i, (n, k, s, p) in enumerate(zip(n_channels[1:], kernels, strides, paddings), 1):
            li += [nn.Conv2d(n_channels[i-1], n, kernel_size=k, stride=s, padding=p), 
                   nn.ReLU(inplace=True)]
            
        self.enc = nn.Sequential(*li)
        self.enc_mu = nn.Conv2d(in_channels=128, out_channels=latent_dim, 
                                kernel_size=4, stride=1, padding=0)
        self.enc_var = nn.Conv2d(in_channels=128, out_channels=latent_dim, 
                                 kernel_size=4, stride=1, padding=0)
        
    def forward(self, x):
        x = self.enc(x)
        # Be careful not to squeeze the batch dimension if batch size = 1
        mu = self.enc_mu(x).squeeze(3).squeeze(2)
        log_var = self.enc_var(x).squeeze(3).squeeze(2)
        return mu, log_var
    
class DecSVHN(nn.Module):
    def __init__(self, latent_dim):
        super(DecSVHN, self).__init__()  
        self.latent_dim = latent_dim
        
        n_channels = (latent_dim, 128, 64, 32, 3)
        kernels = (4, 4, 4, 4)
        strides = (1, 2, 2, 2)
        paddings = (0, 1, 1, 1)
        li = []
        for i, (n, k, s, p) in enumerate(zip(n_channels[1:], kernels, strides, paddings), 1):
            li += [nn.ConvTranspose2d(n_channels[i-1], n, kernel_size=k, stride=s, padding=p), 
                   nn.ReLU(inplace=True)]
        li[-1] = nn.Sigmoid()
        
        self.dec = nn.Sequential(*li)
        
    def forward(self, x):
        x = self.dec(x)
        return x

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
MNIST_PATH = os.path.join(HOME_PATH, 'Datasets/MNIST/MNIST/processed/%s.pt')
SVHN_PATH = os.path.join(HOME_PATH, 'Datasets/SVHN/%s_32x32.mat')

joint_dataset_train = poisevae.utils.MNIST_SVHN(mnist_pt_path=MNIST_PATH % 'train', svhn_mat_path=SVHN_PATH % 'train')
joint_dataset_test = poisevae.utils.MNIST_SVHN(mnist_pt_path=MNIST_PATH % 'test', svhn_mat_path=SVHN_PATH % 'test')

# %%
batch_size = 128
train_loader = torch.utils.data.DataLoader(joint_dataset_train, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(joint_dataset_test, batch_size=batch_size, shuffle=True)
len(train_loader), len(test_loader)
# Out:
# (469, 79)

# %%
lat1, lat2 = 20, 20
enc_mnist = EncMNIST(lat1).to(device)
dec_mnist = DecMNIST(lat1).to(device)
enc_svhn = EncSVHN(lat2).to(device)
dec_svhn = DecSVHN(lat2).to(device)

def MSELoss(input, target):
    loss = nn.functional.mse_loss(input, target, reduction='sum') #/ batch_size
    return loss
    
def MAELoss(input, target):
    loss = nn.functional.l1_loss(input, target, reduction='sum') #/ batch_size
    return loss
    
vae = poisevae.POISEVAE([enc_mnist, enc_svhn], [dec_mnist, dec_svhn], [MSELoss, MSELoss], 
                        latent_dims=[lat1, (lat2, 1, 1)]).to(device)

# %%
# for i in vae.named_parameters():
#     print(i[0])

# %%
optimizer = optim.Adam(vae.parameters(), lr=5e-4)

# %%
PATH = os.path.join(HOME_PATH, 'Datasets/MNIST_SVHN_train_results/')

# %%
epoch = 0
# try:
#     vae, optimizer, epoch = load_checkpoint(vae, optimizer, sorted(glob.glob(PATH + 'train*.pt'))[-1])
# except:
#     pass

# %%
train_loss = []
test_loss = []
epochs = 100 + epoch
for epoch in range(epoch, epochs):
    print(f"Epoch {epoch+1} of {epochs}")
    train_epoch_losses = poisevae.utils.train(vae, train_loader, optimizer, epoch)
    train_loss.append(train_epoch_losses)
    ret = poisevae.utils.test(vae, test_loader, epoch, record_idx=(2, 3), return_latents=True)
    test_epoch_losses, labels, latent_info = ret[:4], ret[-2], ret[-1]
    test_loss.append(test_epoch_losses)
    print(f"Train Loss: %.4f\n\tRec: %.4f, %.4f\n\tKLD Loss %.4f" % train_epoch_losses)
    print(f"Test Loss: %.4f\n\tRec: %.4f, %.4f\n\tKLD Loss %.4f" % test_epoch_losses)
    if (epoch+1) % 10 == 0 and epoch > 0:
        poisevae.utils.save_checkpoint(vae, optimizer, PATH + 'training_%d.pt' % (epoch+1), epoch+1)
# Out:
# Epoch 1 of 100
# Train Loss: 106.9927
# 	Rec: 45.2193, 63.1731
# 	KLD Loss -1.3997
# Test Loss: 86.4242
# 	Rec: 36.8055, 50.6652
# 	KLD Loss -1.0466
# Epoch 2 of 100
# Train Loss: 74.6968
# 	Rec: 34.6429, 39.9016
# 	KLD Loss 0.1523
# Test Loss: 72.8054
# 	Rec: 33.1153, 39.7482
# 	KLD Loss -0.0581
# Epoch 3 of 100
# Train Loss: 66.8488
# 	Rec: 31.2740, 34.9376
# 	KLD Loss 0.6372
# Test Loss: 72.1656
# 	Rec: 29.5582, 41.8207
# 	KLD Loss 0.7868
# Epoch 4 of 100
# Train Loss: 61.9090
# 	Rec: 29.2580, 31.8059
# 	KLD Loss 0.8450
# Test Loss: 62.1929
# 	Rec: 28.5202, 32.6723
# 	KLD Loss 1.0005
# Epoch 5 of 100
# Train Loss: 58.6599
# 	Rec: 27.7637, 30.0108
# 	KLD Loss 0.8854
# Test Loss: 59.9821
# 	Rec: 27.2553, 31.6493
# 	KLD Loss 1.0776
# Epoch 6 of 100
# Train Loss: 56.3490
# 	Rec: 26.7035, 28.7045
# 	KLD Loss 0.9410
# Test Loss: 56.8832
# 	Rec: 26.2261, 29.8647
# 	KLD Loss 0.7924
# Epoch 7 of 100
# Train Loss: 54.6808
# 	Rec: 25.8321, 27.9834
# 	KLD Loss 0.8652
# Test Loss: 55.3936
# 	Rec: 25.4263, 29.0266
# 	KLD Loss 0.9408
# Epoch 8 of 100
# Train Loss: 53.7036
# 	Rec: 25.1672, 27.7144
# 	KLD Loss 0.8220
# Test Loss: 54.5540
# 	Rec: 24.7213, 28.9269
# 	KLD Loss 0.9058
# Epoch 9 of 100
# Train Loss: 52.1039
# 	Rec: 24.5307, 26.8555
# 	KLD Loss 0.7176
# Test Loss: 54.8964
# 	Rec: 23.9038, 30.3513
# 	KLD Loss 0.6413
# Epoch 10 of 100
# Train Loss: 51.0874
# 	Rec: 24.0728, 26.3929
# 	KLD Loss 0.6217
# Test Loss: 52.5740
# 	Rec: 23.7496, 28.1303
# 	KLD Loss 0.6940
# Epoch 11 of 100
# Train Loss: 50.5475
# 	Rec: 23.6614, 26.3133
# 	KLD Loss 0.5728
# Test Loss: 52.7186
# 	Rec: 23.5778, 27.9896
# 	KLD Loss 1.1512
# Epoch 12 of 100
# Train Loss: 49.9592
# 	Rec: 23.3215, 26.0801
# 	KLD Loss 0.5576
# Test Loss: 50.7322
# 	Rec: 22.8540, 27.5187
# 	KLD Loss 0.3595
# Epoch 13 of 100
# Train Loss: 49.3259
# 	Rec: 23.0256, 25.8167
# 	KLD Loss 0.4836
# Test Loss: 50.4594
# 	Rec: 22.6202, 27.7300
# 	KLD Loss 0.1092
# Epoch 14 of 100
# Train Loss: 48.8042
# 	Rec: 22.7430, 25.6100
# 	KLD Loss 0.4512
# Test Loss: 50.9065
# 	Rec: 22.3437, 28.4073
# 	KLD Loss 0.1555
# Epoch 15 of 100
# Train Loss: 48.2677
# 	Rec: 22.5152, 25.3510
# 	KLD Loss 0.4015
# Test Loss: 50.5229
# 	Rec: 22.2786, 27.9175
# 	KLD Loss 0.3268
# Epoch 16 of 100
# Train Loss: 47.8720
# 	Rec: 22.2738, 25.2831
# 	KLD Loss 0.3151
# Test Loss: 49.1579
# 	Rec: 21.8406, 26.9016
# 	KLD Loss 0.4157
# Epoch 17 of 100
# Train Loss: 47.6371
# 	Rec: 22.0901, 25.2013
# 	KLD Loss 0.3457
# Test Loss: 49.1414
# 	Rec: 22.2922, 26.4662
# 	KLD Loss 0.3831
# Epoch 18 of 100
# Train Loss: 47.1370
# 	Rec: 21.9105, 24.9761
# 	KLD Loss 0.2504
# Test Loss: 48.9514
# 	Rec: 21.8007, 26.7722
# 	KLD Loss 0.3784
# Epoch 19 of 100
# Train Loss: 46.9647
# 	Rec: 21.7475, 24.9475
# 	KLD Loss 0.2698
# Test Loss: 50.2502
# 	Rec: 21.3739, 28.2702
# 	KLD Loss 0.6061
# Epoch 20 of 100
# Train Loss: 46.7502
# 	Rec: 21.5878, 24.9420
# 	KLD Loss 0.2204
# Test Loss: 47.9040
# 	Rec: 21.2761, 26.3972
# 	KLD Loss 0.2307
# Epoch 21 of 100
# Train Loss: 46.4199
# 	Rec: 21.4351, 24.8110
# 	KLD Loss 0.1738
# Test Loss: 47.5515
# 	Rec: 21.4130, 25.8744
# 	KLD Loss 0.2640
# Epoch 22 of 100
# Train Loss: 46.2347
# 	Rec: 21.3296, 24.7100
# 	KLD Loss 0.1951
# Test Loss: 47.4297
# 	Rec: 21.0891, 26.6067
# 	KLD Loss -0.2661
# Epoch 23 of 100
# Train Loss: 45.8949
# 	Rec: 21.2136, 24.5320
# 	KLD Loss 0.1492
# Test Loss: 47.2248
# 	Rec: 20.9068, 26.4643
# 	KLD Loss -0.1463
# Epoch 24 of 100
# Train Loss: 45.6785
# 	Rec: 21.1085, 24.4394
# 	KLD Loss 0.1305
# Test Loss: 46.9235
# 	Rec: 20.9286, 25.8409
# 	KLD Loss 0.1539
# Epoch 25 of 100
# Train Loss: 45.6101
# 	Rec: 21.0024, 24.4789
# 	KLD Loss 0.1288
# Test Loss: 47.0599
# 	Rec: 21.0298, 26.0083
# 	KLD Loss 0.0218
# Epoch 26 of 100
# Train Loss: 45.3622
# 	Rec: 20.9102, 24.3543
# 	KLD Loss 0.0977
# Test Loss: 46.7681
# 	Rec: 20.7718, 25.8839
# 	KLD Loss 0.1124
# Epoch 27 of 100
# Train Loss: 45.4481
# 	Rec: 20.8238, 24.5031
# 	KLD Loss 0.1213
# Test Loss: 46.3759
# 	Rec: 20.6901, 25.6709
# 	KLD Loss 0.0148
# Epoch 28 of 100
# Train Loss: 45.1489
# 	Rec: 20.7486, 24.3326
# 	KLD Loss 0.0677
# Test Loss: 46.6230
# 	Rec: 20.7006, 25.5842
# 	KLD Loss 0.3382
# Epoch 29 of 100
# Train Loss: 44.9828
# 	Rec: 20.6678, 24.1907
# 	KLD Loss 0.1243
# Test Loss: 46.9290
# 	Rec: 20.4090, 26.4493
# 	KLD Loss 0.0707
# Epoch 30 of 100
# Train Loss: 44.6851
# 	Rec: 20.5833, 24.0558
# 	KLD Loss 0.0460
# Test Loss: 45.4478
# 	Rec: 20.3796, 25.2762
# 	KLD Loss -0.2079
# Epoch 31 of 100
# Train Loss: 44.7386
# 	Rec: 20.5116, 24.1253
# 	KLD Loss 0.1017
# Test Loss: 45.9600
# 	Rec: 20.3747, 25.7225
# 	KLD Loss -0.1372
# Epoch 32 of 100
# Train Loss: 44.6770
# 	Rec: 20.4318, 24.1212
# 	KLD Loss 0.1239
# Test Loss: 45.6533
# 	Rec: 20.3514, 25.2477
# 	KLD Loss 0.0542
# Epoch 33 of 100
# Train Loss: 44.3993
# 	Rec: 20.3814, 23.8966
# 	KLD Loss 0.1213
# Test Loss: 46.7137
# 	Rec: 20.2874, 26.7135
# 	KLD Loss -0.2872
# Epoch 34 of 100
# Train Loss: 44.2159
# 	Rec: 20.3012, 23.7747
# 	KLD Loss 0.1401
# Test Loss: 45.3781
# 	Rec: 20.1151, 25.6231
# 	KLD Loss -0.3601
# Epoch 35 of 100
# Train Loss: 44.2980
# 	Rec: 20.2655, 24.0001
# 	KLD Loss 0.0324
# Test Loss: 45.6043
# 	Rec: 20.0948, 25.6749
# 	KLD Loss -0.1654
# Epoch 36 of 100
# Train Loss: 44.0789
# 	Rec: 20.2072, 23.8171
# 	KLD Loss 0.0546
# Test Loss: 45.4396
# 	Rec: 20.2089, 25.4089
# 	KLD Loss -0.1782
# Epoch 37 of 100
# Train Loss: 44.0875
# 	Rec: 20.1477, 23.9279
# 	KLD Loss 0.0118
# Test Loss: 45.0848
# 	Rec: 20.0003, 25.1590
# 	KLD Loss -0.0744
# Epoch 38 of 100
# Train Loss: 44.0666
# 	Rec: 20.1302, 23.8802
# 	KLD Loss 0.0562
# Test Loss: 45.2379
# 	Rec: 19.9653, 25.5887
# 	KLD Loss -0.3161
# Epoch 39 of 100
# Train Loss: 43.8226
# 	Rec: 20.0358, 23.7867
# 	KLD Loss 0.0001
# Test Loss: 45.2921
# 	Rec: 19.9501, 25.0921
# 	KLD Loss 0.2499
# Epoch 40 of 100
# Train Loss: 43.6952
# 	Rec: 20.0145, 23.6036
# 	KLD Loss 0.0771
# Test Loss: 44.2836
# 	Rec: 19.8746, 24.7972
# 	KLD Loss -0.3882
# Epoch 41 of 100
# Train Loss: 43.7231
# 	Rec: 19.9625, 23.7097
# 	KLD Loss 0.0509
# Test Loss: 45.1874
# 	Rec: 19.9234, 25.1416
# 	KLD Loss 0.1223
# Epoch 42 of 100
# Train Loss: 43.4877
# 	Rec: 19.8893, 23.5545
# 	KLD Loss 0.0439
# Test Loss: 44.3828
# 	Rec: 19.9293, 24.5030
# 	KLD Loss -0.0496
# Epoch 43 of 100
# Train Loss: 43.5717
# 	Rec: 19.8617, 23.6516
# 	KLD Loss 0.0584
# Test Loss: 45.2470
# 	Rec: 19.8206, 25.6562
# 	KLD Loss -0.2298
# Epoch 44 of 100
# Train Loss: 43.4650
# 	Rec: 19.8306, 23.5473
# 	KLD Loss 0.0870
# Test Loss: 44.4629
# 	Rec: 19.7648, 24.8111
# 	KLD Loss -0.1130
# Epoch 45 of 100
# Train Loss: 43.2775
# 	Rec: 19.7778, 23.4566
# 	KLD Loss 0.0430
# Test Loss: 44.6065
# 	Rec: 19.8708, 24.6485
# 	KLD Loss 0.0872
# Epoch 46 of 100
# Train Loss: 43.1158
# 	Rec: 19.7672, 23.2997
# 	KLD Loss 0.0490
# Test Loss: 44.6266
# 	Rec: 19.7156, 25.2044
# 	KLD Loss -0.2933
# Epoch 47 of 100
# Train Loss: 43.1364
# 	Rec: 19.7280, 23.3709
# 	KLD Loss 0.0374
# Test Loss: 43.8837
# 	Rec: 19.6256, 24.6221
# 	KLD Loss -0.3640
# Epoch 48 of 100
# Train Loss: 43.0218
# 	Rec: 19.6796, 23.2877
# 	KLD Loss 0.0546
# Test Loss: 44.4234
# 	Rec: 19.6816, 24.8552
# 	KLD Loss -0.1134
# Epoch 49 of 100
# Train Loss: 43.0222
# 	Rec: 19.6391, 23.3799
# 	KLD Loss 0.0032
# Test Loss: 44.4551
# 	Rec: 19.6116, 25.0529
# 	KLD Loss -0.2094
# Epoch 50 of 100
# Train Loss: 43.0136
# 	Rec: 19.5928, 23.3778
# 	KLD Loss 0.0429
# Test Loss: 44.7918
# 	Rec: 19.6655, 25.1308
# 	KLD Loss -0.0046
# Epoch 51 of 100
# Train Loss: 42.8487
# 	Rec: 19.5950, 23.2146
# 	KLD Loss 0.0391
# Test Loss: 45.6951
# 	Rec: 19.5369, 26.2068
# 	KLD Loss -0.0487
# Epoch 52 of 100
# Train Loss: 42.9026
# 	Rec: 19.5531, 23.3009
# 	KLD Loss 0.0486
# Test Loss: 44.0078
# 	Rec: 19.4420, 24.8794
# 	KLD Loss -0.3137
# Epoch 53 of 100
# Train Loss: 42.6712
# 	Rec: 19.5474, 23.0825
# 	KLD Loss 0.0412
# Test Loss: 43.9593
# 	Rec: 19.4217, 24.7913
# 	KLD Loss -0.2538
# Epoch 54 of 100
# Train Loss: 42.6556
# 	Rec: 19.4807, 23.1098
# 	KLD Loss 0.0651
# Test Loss: 43.9580
# 	Rec: 19.3435, 24.7489
# 	KLD Loss -0.1344
# Epoch 55 of 100
# Train Loss: 42.5931
# 	Rec: 19.4781, 23.1135
# 	KLD Loss 0.0015
# Test Loss: 43.3676
# 	Rec: 19.3578, 24.3029
# 	KLD Loss -0.2931
# Epoch 56 of 100
# Train Loss: 42.5786
# 	Rec: 19.4369, 23.0928
# 	KLD Loss 0.0489
# Test Loss: 43.7063
# 	Rec: 19.3860, 24.5206
# 	KLD Loss -0.2003
# Epoch 57 of 100
# Train Loss: 42.5323
# 	Rec: 19.4105, 23.0916
# 	KLD Loss 0.0303
# Test Loss: 44.0621
# 	Rec: 19.4708, 24.5581
# 	KLD Loss 0.0332
# Epoch 58 of 100
# Train Loss: 42.4059
# 	Rec: 19.3649, 23.0222
# 	KLD Loss 0.0188
# Test Loss: 43.9978
# 	Rec: 19.3792, 24.8544
# 	KLD Loss -0.2358
# Epoch 59 of 100
# Train Loss: 42.4642
# 	Rec: 19.3754, 23.1041
# 	KLD Loss -0.0152
# Test Loss: 43.7401
# 	Rec: 19.4231, 24.5458
# 	KLD Loss -0.2287
# Epoch 60 of 100
# Train Loss: 42.2260
# 	Rec: 19.3100, 22.9457
# 	KLD Loss -0.0296
# Test Loss: 44.0883
# 	Rec: 19.2956, 24.8731
# 	KLD Loss -0.0804
# Epoch 61 of 100
# Train Loss: 42.4483
# 	Rec: 19.3157, 23.0457
# 	KLD Loss 0.0869
# Test Loss: 43.6765
# 	Rec: 19.1664, 24.7832
# 	KLD Loss -0.2730
# Epoch 62 of 100
# Train Loss: 42.3630
# 	Rec: 19.2956, 23.0144
# 	KLD Loss 0.0529
# Test Loss: 44.2696
# 	Rec: 19.1994, 24.9409
# 	KLD Loss 0.1294
# Epoch 63 of 100
# Train Loss: 42.2066
# 	Rec: 19.2506, 22.9492
# 	KLD Loss 0.0068
# Test Loss: 45.1952
# 	Rec: 19.1296, 26.1772
# 	KLD Loss -0.1116
# Epoch 64 of 100
# Train Loss: 42.0671
# 	Rec: 19.2422, 22.8193
# 	KLD Loss 0.0056
# Test Loss: 43.7416
# 	Rec: 19.2157, 24.7534
# 	KLD Loss -0.2275
# Epoch 65 of 100
# Train Loss: 42.2661
# 	Rec: 19.2261, 22.9774
# 	KLD Loss 0.0625
# Test Loss: 43.4246
# 	Rec: 19.1356, 24.5225
# 	KLD Loss -0.2335
# Epoch 66 of 100
# Train Loss: 42.0830
# 	Rec: 19.2043, 22.8558
# 	KLD Loss 0.0229
# Test Loss: 43.7848
# 	Rec: 19.1567, 25.0906
# 	KLD Loss -0.4625
# Epoch 67 of 100
# Train Loss: 41.9281
# 	Rec: 19.1575, 22.7540
# 	KLD Loss 0.0167
# Test Loss: 43.4721
# 	Rec: 19.1209, 24.3705
# 	KLD Loss -0.0193
# Epoch 68 of 100
# Train Loss: 42.0590
# 	Rec: 19.1744, 22.9003
# 	KLD Loss -0.0156
# Test Loss: 43.5092
# 	Rec: 19.0768, 24.6459
# 	KLD Loss -0.2134
# Epoch 69 of 100
# Train Loss: 41.9914
# 	Rec: 19.1511, 22.7951
# 	KLD Loss 0.0452
# Test Loss: 43.4912
# 	Rec: 19.0892, 24.6258
# 	KLD Loss -0.2237
# Epoch 70 of 100
# Train Loss: 42.0065
# 	Rec: 19.0992, 22.8979
# 	KLD Loss 0.0095
# Test Loss: 42.9272
# 	Rec: 19.0363, 24.3435
# 	KLD Loss -0.4526
# Epoch 71 of 100
# Train Loss: 41.9085
# 	Rec: 19.1030, 22.8216
# 	KLD Loss -0.0161
# Test Loss: 45.3099
# 	Rec: 19.0846, 26.3741
# 	KLD Loss -0.1488
# Epoch 72 of 100
# Train Loss: 41.9791
# 	Rec: 19.0879, 22.8816
# 	KLD Loss 0.0096
# Test Loss: 42.9063
# 	Rec: 18.9511, 24.4460
# 	KLD Loss -0.4908
# Epoch 73 of 100
# Train Loss: 41.9751
# 	Rec: 19.0882, 22.8679
# 	KLD Loss 0.0190
# Test Loss: 43.6881
# 	Rec: 19.1129, 24.5819
# 	KLD Loss -0.0067
# Epoch 74 of 100
# Train Loss: 41.8138
# 	Rec: 19.0635, 22.7595
# 	KLD Loss -0.0093
# Test Loss: 43.1836
# 	Rec: 18.9577, 24.3766
# 	KLD Loss -0.1508
# Epoch 75 of 100
# Train Loss: 41.5676
# 	Rec: 19.0251, 22.5728
# 	KLD Loss -0.0303
# Test Loss: 42.9472
# 	Rec: 18.9210, 24.1031
# 	KLD Loss -0.0769
# Epoch 76 of 100
# Train Loss: 41.8009
# 	Rec: 19.0102, 22.7153
# 	KLD Loss 0.0754
# Test Loss: 43.1576
# 	Rec: 18.9681, 24.4629
# 	KLD Loss -0.2735
# Epoch 77 of 100
# Train Loss: 41.7443
# 	Rec: 19.0163, 22.6977
# 	KLD Loss 0.0303
# Test Loss: 43.5702
# 	Rec: 18.9817, 24.6286
# 	KLD Loss -0.0401
# Epoch 78 of 100
# Train Loss: 41.7215
# 	Rec: 18.9904, 22.6867
# 	KLD Loss 0.0445
# Test Loss: 43.2746
# 	Rec: 18.9281, 24.3930
# 	KLD Loss -0.0464
# Epoch 79 of 100
# Train Loss: 41.7013
# 	Rec: 18.9775, 22.7037
# 	KLD Loss 0.0201
# Test Loss: 43.1359
# 	Rec: 18.9684, 24.2661
# 	KLD Loss -0.0986
# Epoch 80 of 100
# Train Loss: 41.6613
# 	Rec: 18.9735, 22.6210
# 	KLD Loss 0.0667
# Test Loss: 43.3899
# 	Rec: 18.9281, 24.8653
# 	KLD Loss -0.4036
# Epoch 81 of 100
# Train Loss: 41.5257
# 	Rec: 18.9638, 22.5716
# 	KLD Loss -0.0097
# Test Loss: 42.9631
# 	Rec: 18.9092, 24.1949
# 	KLD Loss -0.1411
# Epoch 82 of 100
# Train Loss: 41.6215
# 	Rec: 18.9588, 22.6562
# 	KLD Loss 0.0066
# Test Loss: 42.9037
# 	Rec: 18.9467, 24.4063
# 	KLD Loss -0.4493
# Epoch 83 of 100
# Train Loss: 41.4614
# 	Rec: 18.9215, 22.4801
# 	KLD Loss 0.0599
# Test Loss: 43.4281
# 	Rec: 18.9224, 24.6201
# 	KLD Loss -0.1144
# Epoch 84 of 100
# Train Loss: 41.5829
# 	Rec: 18.8965, 22.6706
# 	KLD Loss 0.0158
# Test Loss: 43.4437
# 	Rec: 18.8297, 24.7758
# 	KLD Loss -0.1617
# Epoch 85 of 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_242581/3727929074.py in <module>
#       4 for epoch in range(epoch, epochs):
#       5     print(f"Epoch {epoch+1} of {epochs}")
# ----> 6     train_epoch_losses = poisevae.utils.train(vae, train_loader, optimizer, epoch)
#       7     train_loss.append(train_epoch_losses)
#       8     ret = poisevae.utils.test(vae, test_loader, epoch, record_idx=(2, 3), return_latents=True)
#
# ~/vae_project/POISEVAE/poisevae/utils/functions.py in train(model, joint_dataloader, optimizer, epoch, record_idx, return_latents, progress_bar, device, dtype)
#      57         optimizer.zero_grad()
#      58
# ---> 59         results = model([data[i].to(device=device, dtype=dtype) for i in range(model.M)])
#      60
#      61         for i, val in enumerate(results['rec_losses']):
#
# ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/vae_project/POISEVAE/poisevae/POISE_VAE.py in forward(self, x)
#     239
#     240         # KL loss
# --> 241         kls = self.kl_div.calc(G, z_gibbs_posteriors, z_gibbs_priors, mu, var)
#     242         KL_loss  = torch.sum(torch.stack(kls))
#     243
#
# ~/vae_project/POISEVAE/poisevae/kl_divergence_calculator.py in calc(self, G, z, z_priors, mu, var)
#      37
#      38         for i in range(batch_size):
# ---> 39             T_prior_kron[i,:] = torch.kron(T1_prior_unsq[i,:], T2_prior_unsq[i,:])
#      40             T_post_kron[i,:] = torch.kron(T1_post_unsq[i,:], T2_post_unsq[i,:])
#      41
#
# KeyboardInterrupt:

# %%
train_loss = np.array(train_loss).T
test_loss = np.array(test_loss).T

# %%
poisevae.utils.save_latent_info(latent_info, PATH)

# %%
plt.plot(test_loss[-1])

# %%
plt.plot(train_loss[-1])

# %%
fig, ax = plt.subplots(ncols=2, sharex='all', sharey='all', figsize=(9, 4))

for i, label in enumerate(('Total', 'Rec1', 'Rec2', 'KLD')):
    ax[0].plot(train_loss[i], label=label)
    ax[1].plot(test_loss[i], label=label)
ax[0].set_title('Train')
ax[1].set_title('Validation')
fig.legend(*ax[0].get_legend_handles_labels(), fontsize='small')
fig.tight_layout()

# %%
with torch.no_grad():
    for i, data in enumerate(test_loader):
        results = vae([data[0].to(device, dtype=torch.float32), data[1].to(device, dtype=torch.float32)])
        break

# %%
ncols = min(len(results['x_rec'][0]), 15)
fig, ax = plt.subplots(nrows=2, ncols=ncols, figsize=(10, 1.4))
for i, aux in enumerate(zip(data[0], results['x_rec'][0])):
    if i >= ncols:
        break
    for j, im in enumerate(aux):
        ax[j, i].imshow(im.cpu().numpy().reshape(28, 28), cmap='gray')
        ax[j, i].set_xticks([])
        ax[j, i].set_yticks([])
ax[1, 0].set_ylabel('Rec', fontsize=24)
fig.subplots_adjust(wspace=0, hspace=0)
fig.savefig(PATH + 'MNISTRec.pdf', dpi=300)

# %%
ncols = min(len(results['x_rec'][0]), 20)
nrows = 2 * int(np.floor(len(results['x_rec'][0]) / 20))
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 1.5*nrows/2))
for i, aux in enumerate(zip(data[0], results['x_rec'][0])):
    if i >= nrows / 2 * 20:
        break
    for j, im in enumerate(aux):
        ax[j+i//20*2, i%20].imshow(im.cpu().numpy().reshape(28, 28), cmap='gray')
        ax[j+i//20*2, i%20].set_xticks([])
        ax[j+i//20*2, i%20].set_yticks([])
    ax[1+i//20*2, 0].set_ylabel('Rec', fontsize=24)
fig.tight_layout(pad=0)
fig.savefig(PATH + 'MNISTRecExtra.pdf', dpi=300)

# %%
ncols = min(len(results['x_rec'][1]), 15)
fig, ax = plt.subplots(nrows=2, ncols=ncols, figsize=(10, 1.4))
for i, aux in enumerate(zip(data[1], results['x_rec'][1])):
    if i >= ncols:
        break
    for j, im in enumerate(aux):
        ax[j, i].imshow(im.cpu().numpy().transpose(1, 2, 0))
        ax[j, i].set_xticks([])
        ax[j, i].set_yticks([])
ax[1, 0].set_ylabel('Rec', fontsize=24)
fig.subplots_adjust(wspace=0, hspace=0)
fig.savefig(PATH + 'SVHNRec.pdf', dpi=300)

# %%
ncols = min(len(results['x_rec'][1]), 20)
nrows = 2 * int(np.floor(len(results['x_rec'][1]) / 20))
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(15, 1.5*nrows/2))
for i, aux in enumerate(zip(data[1], results['x_rec'][1])):
    if i >= nrows / 2 * 20:
        break
    for j, im in enumerate(aux):
        ax[j+i//20*2, i%20].imshow(im.cpu().numpy().transpose(1, 2, 0), cmap='gray')
        ax[j+i//20*2, i%20].set_xticks([])
        ax[j+i//20*2, i%20].set_yticks([])
    ax[1+i//20*2, 0].set_ylabel('Rec', fontsize=24)
fig.tight_layout(pad=0)
fig.savefig(PATH + 'SVHNRecExtra.pdf', dpi=300)
